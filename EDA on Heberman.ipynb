# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("./dataset/haberman.csv")

# %%
df.columns
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(5)
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
df.shape
# Out:
# (305, 4)

# %%
#df.iloc[0] = ['Age','Op_Year','axil_nodes','Surv_status'] 
df.columns=["Age","Op_Year","axil_node","Surv_status"]

# %%
df.head(5)
# Out:
#    Age  Op_Year  axil_node  Surv_status
# 0   30       62          3            1
# 1   30       65          0            1
# 2   31       59          2            1
# 3   31       65          4            1
# 4   33       58         10            1

# %%
df.shape
# Out:
# (305, 4)

# %%
df["Surv_status"].value_counts()
# Out:
# 1    224
# 2     81
# Name: Surv_status, dtype: int64

# %% [markdown]
# # Objective

# %% [markdown]
# Our Objective is to classify the people who will leave more than five year or less

# %% [markdown]
# # Dataset Distribution

# %% [markdown]
# This dataset is imbalanaced dataset and it has two classe.
#
# Total Number of Point= 305
#
# First class: 1-> The patient survive 5 year or longer
#
# Second class: 2-> The patient survive 5 year or smaller

# %% [markdown]
# # Dataset Distribution

# %% [markdown]
# 1---> contains 224 patient
# 2---> contains 81  patient

# %%
df_1=df.loc[df["Surv_status"]==1]
df_2=df.loc[df["Surv_status"]==2]

# %%
print(df_1.shape)
print(df_2.shape)
# Out:
# (224, 4)
# (81, 4)

# %%
df_1.sample(5)
# Out:
#      Age  Op_Year  axil_node  Surv_status
# 261   65       58          0            1
# 10    34       61         10            1
# 139   51       65          0            1
# 256   64       68          0            1
# 121   49       61          0            1

# %%
df_2.sample(5)
# Out:
#      Age  Op_Year  axil_node  Surv_status
# 189   56       65          9            2
# 238   62       58          0            2
# 143   52       62          3            2
# 80    45       66          0            2
# 114   49       64         10            2

# %%
sns.boxplot(x="Surv_status",y="Op_Year",data=df)
plt.show()

# %%
sns.boxplot(x="Surv_status",y="Age",data=df)
plt.show()

# %%
sns.boxplot(x="Surv_status",y="axil_node",data=df)
plt.show()

# %% [markdown]
# # Violinplot

# %%
sns.violinplot(x="Surv_status",y="axil_node",data=df)
plt.show()

# %%
sns.violinplot(x="Surv_status",y="Age",data=df)
plt.show()

# %%
sns.violinplot(x="Surv_status",y="Op_Year",data=df)
plt.show()

# %%
plt.close()
sns.set_style("whitegrid")
sns.pairplot(df,hue="Surv_status",height=4)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# 1. No feature is directly applicable for the classification
# 2. Here we can't directly apply the if else statement for the classification
