# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("./dataset/Irisdataset.csv")

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.shape
# Out:
# (100, 6)

# %%
df["Species"].value_counts()
# Out:
#  1    50
# -1    50
# Name: Species, dtype: int64

# %%
df.sample(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 36  37            5.5           3.5            1.3           0.2        1
# 51  52            6.4           3.2            4.5           1.5       -1
# 27  28            5.2           3.5            1.5           0.2        1
# 61  62            5.9           3.0            4.2           1.5       -1
# 83  84            6.0           2.7            5.1           1.6       -1

# %%
df.sample(5)
df=df.iloc[:,1:]
df.sample(5)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 23            5.1           3.3            1.7           0.5        1
# 3             4.6           3.1            1.5           0.2        1
# 55            5.7           2.8            4.5           1.3       -1
# 52            6.9           3.1            4.9           1.5       -1
# 68            6.2           2.2            4.5           1.5       -1

# %%
plt.scatter(df["SepalWidthCm"],df["PetalLengthCm"])
plt.xlabel("SepalWidthCm")
plt.ylabel("PetalLengthCm")
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(df,hue="Species",height=4).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()
plt.show()

# %%
plt.close()
sns.set_style("whitegrid")
sns.pairplot(df,hue="Species",height=4)
plt.show()

# %% [markdown]
# # Histogram, PDf and CDF

# %%
#taking all the data_frame of particular type
import numpy as np
# we are taking all the dataframe of type iris_setosa in iris_setosa dataframe
iris_setosa=df.loc[df["Species"]==1]
# we are taking all the dataframe of type iris_versicolor in iris_versicolor dataframe
iris_versicolor=df.loc[df["Species"]==-1]

# %%
iris_setosa.shape
# Out:
# (50, 5)

# %%
iris_versicolor.shape
# Out:
# (50, 5)

# %%
# There is one problem in case of the 1D plot is that it doesn't give the accurate count of the number which lies between specific range
plt.plot(iris_setosa["PetalLengthCm"], np.zeros_like(iris_setosa["PetalLengthCm"]))
plt.plot(iris_versicolor["PetalLengthCm"], np.zeros_like(iris_versicolor["PetalLengthCm"]))

# %%
sns.FacetGrid(df,hue="Species", height=5).map(sns.distplot, "PetalLengthCm").add_legend()
plt.show()
# Out:
# /home/ajit/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/ajit/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.plot(iris_setosa["SepalLengthCm"], np.zeros_like(iris_setosa["SepalLengthCm"]))
plt.plot(iris_versicolor["SepalLengthCm"], np.zeros_like(iris_versicolor["SepalLengthCm"]))

# %%
sns.FacetGrid(df,hue="Species", height=5).map(sns.distplot,"SepalLengthCm").add_legend()
plt.show()
# Out:
# /home/ajit/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/ajit/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.plot(iris_setosa["SepalWidthCm"], np.zeros_like(iris_setosa["SepalWidthCm"]))
plt.plot(iris_versicolor["SepalWidthCm"], np.zeros_like(iris_versicolor["SepalWidthCm"]))

# %%
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"SepalWidthCm").add_legend()
plt.show()
# Out:
# /home/ajit/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/ajit/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.plot(iris_setosa["PetalWidthCm"], np.zeros_like(iris_setosa["PetalWidthCm"]))
plt.plot(iris_versicolor["PetalWidthCm"], np.zeros_like(iris_versicolor["PetalWidthCm"]))

# %%
sns.FacetGrid(df,hue="Species",height=5).map(sns.distplot,"PetalWidthCm").add_legend()
plt.show()
# Out:
# /home/ajit/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/ajit/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# #  #cdf

# %%
counts,bin_edges= np.histogram(iris_setosa["PetalLengthCm"], bins=10, density=True)

# %%
print(counts)
# Out:
# [0.22222222 0.22222222 0.44444444 1.55555556 2.66666667 3.11111111
#  1.55555556 0.88888889 0.         0.44444444]

# %%
print(bin_edges)
# Out:
# [1.   1.09 1.18 1.27 1.36 1.45 1.54 1.63 1.72 1.81 1.9 ]

# %%
print(counts.shape)
# Out:
# (10,)

# %%
print(bin_edges.shape)
# Out:
# (11,)

# %%
pdf=counts/sum(counts)

# %%
pdf
# Out:
# array([0.02, 0.02, 0.04, 0.14, 0.24, 0.28, 0.14, 0.08, 0.  , 0.04])

# %%
cdf=np.cumsum(pdf)

# %%
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:],cdf)

# %% [markdown]
# # BoxPlot

# %%
sns.boxplot(x="Species", y="PetalLengthCm", data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sns.boxplot(x="Species", y="SepalLengthCm",data =df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(x="Species", y="SepalWidthCm", data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.boxplot(x="Species", y="PetalWidthCm", data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %% [markdown]
# # Villion Plot

# %%
#Black region is box and thin line is whiskers 
#curve is probability density function
sns.violinplot(x="Species", y="PetalLengthCm",data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %% [markdown]
# # Summarise all the plot

# %% [markdown]
# 1. Univarient-> CDF, PDF, Mean, Median, Percentile and tandard Deviation all thease are the univarient analysis

# %% [markdown]
# 2. Bivarient-> Pair plot is used for the two feature analysis

# %% [markdown]
# 3. Multivarient analysis is done by the taking more than two feature together

# %% [markdown]
# # Multivariat Probability Density , Contour plot

# %%
sns.jointplot(x="PetalLengthCm", y="PetalWidthCm", data=df, kind="kde",hue="Species")
plt.show()
